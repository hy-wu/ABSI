# %%
from src.tokenization import tokenize
tokenize(open('test.absi').read())
# Out:
# [('IDENTIFIER', 'a_in_list1'),
#  ('L_PAREN', '('),
#  ('IDENTIFIER', 'a0'),
#  ('COMMA', ','),
#  ('S', ' '),
#  ('IDENTIFIER', 'as'),
#  ('R_PAREN', ')'),
#  ('S', ' '),
#  ('ASSIGN', '='),
#  ('S', ' '),
#  ('L_BRACE', '{'),
#  ('S', '    '),
#  ('L_PAREN', '('),
#  ('IDENTIFIER', 'a'),
#  ('COLON', ':'),
#  ('IDENTIFIER', 'as'),
#  ('R_PAREN', ')'),
#  ('L_BRACE', '{'),
#  ('S', '        '),
#  ('L_PAREN', '('),
#  ('IDENTIFIER', 'a'),
#  ('S', ' '),
#  ('EQ', '=='),
#  ('S', ' '),
#  ('IDENTIFIER', 'a0'),
#  ('R_PAREN', ')'),
#  ('S', ' '),
#  ('QUESTION', '?'),
#  ('S', ' '),
#  ('L_BRACE', '{'),
#  ('S', '            '),
#  ('RETURN', '>>>'),
#  ('S', ' '),
#  ('TRUE', '_+'),
#  ('SEMICOLON', ';'),
#  ('S', '  '),
#  ('COMMENT', '# future use +'),
#  ('S', '        '),
#  ('R_BRACE', '}'),
#  ('S', '    '),
#  ('R_BRACE', '}'),
#  ('S', '    '),
#  ('RETURN', '>>>'),
#  ('S', ' '),
#  ('FALSE', '_-'),
#  ('SEMICOLON', ';'),
#  ('S', '  '),
#  ('COMMENT', '# future use -'),
# ...
